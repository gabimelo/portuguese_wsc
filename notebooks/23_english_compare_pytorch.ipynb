# %%
import os
os.chdir('..')

# %%
# %run -m src.main
# Out:
# INFO 2019-06-26 18:30:50,348: | epoch   1 |   200/ 2965 batches | lr 20.00 | ms/batch 11.91 | loss  7.62 | ppl  2034.62
# INFO 2019-06-26 18:30:52,728: | epoch   1 |   400/ 2965 batches | lr 20.00 | ms/batch 11.90 | loss  6.80 | ppl   900.38
# INFO 2019-06-26 18:30:55,134: | epoch   1 |   600/ 2965 batches | lr 20.00 | ms/batch 12.02 | loss  6.39 | ppl   594.35
# INFO 2019-06-26 18:30:57,562: | epoch   1 |   800/ 2965 batches | lr 20.00 | ms/batch 12.14 | loss  6.23 | ppl   506.03
# INFO 2019-06-26 18:30:59,992: | epoch   1 |  1000/ 2965 batches | lr 20.00 | ms/batch 12.15 | loss  6.08 | ppl   438.86
# INFO 2019-06-26 18:31:02,426: | epoch   1 |  1200/ 2965 batches | lr 20.00 | ms/batch 12.17 | loss  6.00 | ppl   403.87
# INFO 2019-06-26 18:31:04,861: | epoch   1 |  1400/ 2965 batches | lr 20.00 | ms/batch 12.17 | loss  5.88 | ppl   358.12
# INFO 2019-06-26 18:31:07,300: | epoch   1 |  1600/ 2965 batches | lr 20.00 | ms/batch 12.20 | loss  5.89 | ppl   360.80
# ...
